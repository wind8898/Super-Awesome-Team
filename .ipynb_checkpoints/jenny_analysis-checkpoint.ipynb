# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Take in all of our bikeshare data and read it into pandas
bikeshare_q1 = '2017_Data/Bikeshare Ridership (2017 Q1).csv'
bikeshare_q2 = '2017_Data/Bikeshare Ridership (2017 Q2).csv'
bikeshare_q3 = '2017_Data/Bikeshare Ridership (2017 Q3).csv'
bikeshare_q4 = '2017_Data/Bikeshare Ridership (2017 Q4).csv'

bikeshare_q1_df = pd.read_csv(bikeshare_q1)
bikeshare_q2_df = pd.read_csv(bikeshare_q2)
bikeshare_q3_df = pd.read_csv(bikeshare_q3)
bikeshare_q4_df = pd.read_csv(bikeshare_q4)

# %%
# Merge the four datasets
bikeshare_2017_df = pd.concat([bikeshare_q1_df, bikeshare_q2_df, bikeshare_q3_df, bikeshare_q4_df], sort=True)
bikeshare_2017_df.head(10)
# Out:
#    from_station_id                  from_station_name  to_station_id  \
# 0           7051.0  Wellesley St E / Yonge St Green P         7089.0
# 1           7143.0           Kendal Ave / Bernard Ave         7154.0
# 2           7113.0       Parliament St / Aberdeen Ave         7199.0
# 3           7077.0                 College Park South         7010.0
# 4           7079.0              McGill St / Church St         7047.0
# 5           7021.0                 Bay St / Albert St         7046.0
# 6           7161.0          Beverly St / College St W         7176.0
# 7           7195.0            Ulster St / Bathurst St         7037.0
# 8           7017.0           Widmer St / Adelaide St          7101.0
# 9           7017.0           Widmer St / Adelaide St          7005.0
#
#                        to_station_name  trip_duration_seconds  trip_id  \
# 0                 Church St  / Wood St                    223   712382
# 1              Bathurst Subway Station                    279   712383
# 2            College St W / Markham St                   1394   712384
# 3              King St W / Spadina Ave                    826   712385
# 4        University Ave / Gerrard St W                    279   712386
# 5           Niagara St / Richmond St W                    571   712387
# 6         Bathurst St / Fort York Blvd                   1084   712388
# 7            Bathurst St / Dundas St W                    307   712389
# 8  Lower Sherbourne St / The Esplanade                    647   712390
# 9           University Ave / King St W                    217   712391
#
#   trip_start_time trip_stop_time user_type
# 0   1/1/2017 0:00  1/1/2017 0:03    Member
# 1   1/1/2017 0:00  1/1/2017 0:05    Member
# 2   1/1/2017 0:05  1/1/2017 0:29    Member
# 3   1/1/2017 0:07  1/1/2017 0:21    Member
# 4   1/1/2017 0:08  1/1/2017 0:12    Member
# 5   1/1/2017 0:12  1/1/2017 0:22    Member
# 6   1/1/2017 0:15  1/1/2017 0:33    Member
# 7   1/1/2017 0:15  1/1/2017 0:21    Member
# 8   1/1/2017 0:20  1/1/2017 0:31    Member
# 9   1/1/2017 0:23  1/1/2017 0:27    Member

# %%
# Find all the unique station names
bikeshare_2017_df['from_station_name'].unique()
# Out:
# array(['Wellesley St E / Yonge St Green P', 'Kendal Ave / Bernard Ave',
#        'Parliament St / Aberdeen Ave', 'College Park South',
#        'McGill St / Church St', 'Bay St / Albert St',
#        'Beverly St / College St W', 'Ulster St / Bathurst St',
#        'Widmer St / Adelaide St ', 'King St E / Jarvis St',
#        'Augusta Ave / Dundas St W', 'East Liberty St / Pirandello St',
#        'Bond St / Queen St E', 'King St W / Stafford St',
#        'Simcoe St / Queen St W', 'Gould St / Mutual St',
#        'Dundas St / Yonge St', 'Davenport Rd / Bedford Rd',
#        'Sherbourne St / Wellesley St', 'King St W / Tecumseth St',
#        'University Ave / Elm St', 'Yonge St / Wood St',
#        'Victoria St / Gould St (Ryerson University)',
#        'Richmond St E / Jarvis St Green P', 'Summerhill Station',
#        'Harbord St / Clinton St', '25 York St (ACC/Union Station South)',
#        'Front St W / Blue Jays Way', 'University Ave / Gerrard St W',
#        'College St W / Borden St', 'Bremner Blvd / Spadina Ave',
#        'Navy Wharf Ct. / Bremner Blvd.', 'Dundas St E / Parliament St',
#        'Niagara St / Tecumseth St', 'Chester Station', 'Union Station',
#        'Church St / Bloor St E', 'Palmerston Ave / Vermont Ave',
#        'Queen St W / York St (City Hall)', 'Danforth Ave / Gough Ave',
#        'Simcoe St / Dundas St W', 'Bay St / College St (East Side)',
#        'University Ave / King St W', 'Simcoe St / Wellington St W',
#        'Bay St / St. Joseph St', 'Niagara St / Richmond St W',
#        'Front St / Yonge St (Hockey Hall of Fame)',
#        'Bathurst St / Queens Quay W', 'Queen St W / Gladstone Ave',
#        'Madison Ave / Bloor St W', 'Fort York  Blvd / Capreol Crt',
#        'College St W / Major St', 'Church St / Alexander St',
#        'Dundas St E / Regent Park Blvd', 'Front St / Bay St (North Side)',
#        'King St W / Bay St (West Side)', 'Queens Quay / Yonge St',
#        'Temperance St / Yonge St', 'King St W / Fraser Ave',
#        'Bay St / Davenport Rd', 'Wellington St W / Portland St',
#        'Seaton St / Dundas St E', 'Dundas St W / Crawford St',
#        'Princess St / Adelaide St', 'Queen St W / Close Ave',
#        'Wellington St W / Bay St', 'Jarvis St / Isabella St',
#        'Bloor St W / Christie St', 'Queen St W / Ossington Ave',
#        'Beverly  St / Dundas St W', 'Nelson St / Duncan St',
#        'Bay St / Queens Quay W (Ferry Terminal)',
#        'Queen St W / Dovercourt Rd', 'Queens Quay W / Dan Leckie Way',
#        'Scott St / The Esplanade', 'Bathurst St / Dundas St W',
#        'St George St / Bloor St W', 'Bay St / Wellesley St W',
#        'Phoebe St / Spadina Ave', 'Lower Sherbourne St / The Esplanade',
#        'Roxton Rd / Harbord St', 'Yonge St / Harbour St',
#        '51 Parliament St', 'Gerrard St E / River St',
#        '424 Wellington St. W', 'Ontario Place Blvd / Remembrance Dr',
#        'King St W / Joe Shuster Way',
#        'Dockside Dr / Queens Quay E (Sugar Beach)',
#        'Sherbourne St / Carlton St (Allan Gardens)',
#        'Queen St W / Portland St', 'Wellington St W / Stafford St',
#        'College St W / Crawford St', 'Bathurst St / Fort York Blvd',
#        'Jarvis St / Dundas St E', 'Spadina Ave / Sussex Ave',
#        'Jarvis St / Carlton St', 'York St / Queens Quay W',
#        'Parliament St / Bloor St E',
#        'Mary McCormick Rec Centre (Sheridan Ave)', 'Edward St / Yonge St',
#        'Danforth Ave / Aldridge Ave', 'Bremner Blvd / Rees St',
#        'Queen St W / Spadina Ave', 'College St W / Markham St',
#        'Queen St E / George St (Moss Park)', 'Castle Frank Station',
#        'Cariboo St / Rail Path', 'Yarmouth Rd / Christie St',
#        'Augusta Ave / Denison Sq', 'Trinity St /Front St E',
#        'Ted Rogers Way / Bloor St E', 'Davenport Rd / Avenue Rd',
#        'King St W / Spadina Ave', 'Bay St / Bloor St W',
#        'Danforth Ave / Ellerbeck St', "HTO Park (Queen's Quay W)",
#        'Church St  / Wood St', 'Howard St / Sherbourne St',
#        'King St E / River St', 'Riverdale Park North (Broadview Ave)',
#        'Dundonald St / Church St', 'Queen St W / Shaw St',
#        'Queens Park / Bloor St W', 'St. George St / Hoskin Ave',
#        'Yonge St / Yorkville Ave', 'Salem Ave / Bloor St W',
#        'Elizabeth St / Edward St (Bus Terminal)', 'Metro Hall Plaza',
#        'Hanna Ave / Liberty St', 'Carlton St / Parliament St',
#        "Wellesley St / Queen's Park Cres", 'College St W / Huron St',
#        "Strachan Ave / Princes' Blvd",
#        'Riverdale Park South (Broadview Ave)',
#        'Parliament St / Gerrard St', 'Hayter St / Laplante Ave',
#        'Bloor St W / Dundas St W', 'Bloor St / Brunswick Ave',
#        '80 Clinton St (North of College)',
#        'King St W / Bay St (East Side)',
#        'Jimmie Simpson Park (Queen St E)',
#        'Lower Jarvis St / The Esplanade',
#        'Rusholme Park Cres / College St W',
#        'Queens Quay W / Lower Simcoe St', 'Euclid Ave / Bloor St W',
#        'Huron/ Harbord St', 'Exhibition GO (Atlantic Ave)',
#        'Willcocks St / St. George St', 'Fort York Blvd / Garrison Rd',
#        'Cherry St / Mill St', 'Christie St / Benson Ave (Wychwood Barns)',
#        'Macpherson Ave / Spadina Rd', 'King St W / Douro St',
#        'Glen Edyth Dr / Davenport Rd',
#        '161 Bleecker St (South of Wellesley)',
#        'Sumach St / Carlton St. (Riverdale Farm)',
#        'Front St E / Cherry St', 'Cherry St / Distillery Ln',
#        'Queen St E / Berkely St', 'University Ave / College St',
#        'Queen St E / Sackville St', 'Danforth Ave / Lamb Ave',
#        'Pape Subway Green P', 'Margueretta St / College St W',
#        'Bathurst St / Lennox St', 'Central Tech  (Harbord St)',
#        'Ossington Ave / College St W', 'Sterling Rd / Dundas St W',
#        'Kendal Ave / Spadina Rd', 'Spadina Ave / Willcocks St',
#        'Donlands Station', 'Queen St W / Cowan Ave',
#        'Dufferin St / Sylvan Av (Dufferin Grove Park)',
#        'Ossington Ave / Harrison St', 'Dundas St E / Broadview Ave',
#        'Ossington Ave / Bloor St W', 'Boston Ave / Queen St E',
#        'Bathurst Subway Station', 'Liberty St / Fraser Ave Green P',
#        'Bridgeman Ave / Kendal Ave', 'Claremont St / Dundas St W',
#        'Taddle Creek Park', 'Bloor GO / UP Station/ Rail Path',
#        'Stephenson Ave / Main St', 'Essex St / Christie St',
#        'Bridgeman Ave / Bathurst St', 'Dufferin St / Bloor St',
#        'Mill St / Tannery Rd', 'Davenport Rd / Christie St',
#        'Landsdowne Subway Green P', 'Davenport Rd / Bathurst St',
#        'Dundas St W / Edna Ave', 'Yonge St / Aylmer Ave',
#        'Marlborough Ave / Yonge St', 'Mortimer Ave / Coxwell Ave',
#        'Woodbine Subway Green P (Cedarvale Ave)',
#        'Danforth Ave / Coxwell Ave', 'Danforth Ave / Barrington Ave',
#        'Danforth Ave / Westlake Ave', 'Lansdowne Ave / Whytock Ave',
#        'Princess St / Adelaide St E', 'Widmer St / Adelaide St W',
#        'Michael Sweet Ave / St. Patrick St',
#        'Sherbourne St / Wellesley St E', 'HTO Park (Queens Quay W)',
#        'College St / Major St', 'Beverly St / College St',
#        'College St / Huron St', 'Ossington Ave / College St',
#        'College St / Markham St', 'Wellesley St E / Yonge St (Green P)',
#        'St. George St / Bloor St W', 'College St / Borden St',
#        '424 Wellington St W', 'Margueretta St / College St',
#        'Lansdowne Subway Green P', 'Dundas St W / Yonge St',
#        'Front St W / Yonge St (Hockey Hall of Fame)',
#        'Bloor GO / UP Station (West Toronto Railpath)',
#        'Front St W / Bay St (North Side)', 'College St / Crawford St',
#        'Rusholme Park Cres / College St', 'Queen St E / Larchmount Ave',
#        'The Royal Ontario Museum (Bloor St Entrance)',
#        'Spadina Ave / Adelaide St W', 'Dundas St W / St. Patrick St',
#        'Front St W / Bay St (South Side)',
#        'Lower Spadina Ave / Lake Shore Blvd', 'Bloor St W / Balmuto St',
#        'Roxton Rd / College St', 'Bloor St W / High Park Ave (High Park)',
#        'Base Station', 'Humber Bay Shores Park East',
#        'Lakeshore Blvd W / Ellis Ave',
#        'Lakeshore Blvd W / The Boulevard Club', 'Ward Ave / Wallace Ave',
#        'Humber Bay Shores Park West',
#        'Lake Shore Blvd W / Ontario Dr(Ontario Place)',
#        'Sunnyside - Gus Ryder Pool',
#        'Martin Goodman Trail (Marilyn Bell Park)',
#        'High Park Subway Station', 'Queen St W / Roncesvalles Ave',
#        'Lake Shore Blvd W / Windermere Ave',
#        'Toronto Eaton Centre (Yonge St)', 'Queen St W / James St',
#        'Roncesvalles Ave / Marmaduke St', 'Garden Ave / Roncesvalles Ave',
#        'Dufferin Gate - SMART', 'Queen St W  /  Fuller Ave - SMART',
#        'Dundas St W / Roncesvalles Green P - SMART',
#        'Sorauren/Geoffrey (Sorauren Park) - SMART',
#        'Howard Park Ave / Dundas St W - SMART',
#        'Wallace Ave / Symington Ave - SMART',
#        'St. George St / Russell St - SMART',
#        'Tecumseth St / Queen St W - SMART',
#        'Parkside Dr / Bloor St W - SMART',
#        'Thompson St / Broadview Ave - SMART',
#        'Dundas St E / Pembroke St - SMART',
#        'Baldwin Ave / Spadina Ave - SMART',
#        "Queen's Park Cres E / Grosvenor St - SMART",
#        'Bay St / College St (West Side) - SMART',
#        'Gerrard St E / Broadview - SMART', 'King / Cowan Ave - SMART',
#        'Church St / Dundas St E - SMART', 'Queen St E / Pape Ave - SMART',
#        'Walton St / Elizabeth St - SMART',
#        'Rosehill Ave / Avoca Ave - SMART',
#        '111 Bond St (North of Dundas St E)  - SMART',
#        'John St  / Mercer St - SMART',
#        'Victoria Park Subway Station - SMART',
#        'Bay St / Charles St - SMART', 'Charles St W / Balmuto St - SMART',
#        'Charles St E / Jarvis St - SMART', 'Chorley Park - SMART',
#        'Wright / Sorauren (Sorauren Park) - SMART',
#        'Yonge St / Dundonald St - SMART', '519 Church St - SMART',
#        'Borden St / Bloor St W - SMART',
#        'Stewart St / Bathurst St  - SMART',
#        'Bloor St E / Huntley St - SMART',
#        'Wychwood Ave / Benson Ave - SMART',
#        'Yonge St / Alexander St - SMART',
#        'Adelaide St W / Bay St - SMART',
#        'Bloor St W / Manning Ave - SMART',
#        'Robert St / Bloor St W - SMART', 'York St / King St W - SMART',
#        'Spadina Ave / Harbord St - SMART',
#        'Dovercourt Rd / Harrison St - SMART',
#        'Vanauley St / Queen St W - SMART',
#        'Summerhill Ave / MacLennan Ave - SMART',
#        'Bloor St W / Shaw Ave - SMART', 'Exhibition GO Station',
#        'Fringe Next Stage - 7219'], dtype=object)
